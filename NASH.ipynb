# %%
import yfinance as yf
import pandas as pd
import numpy as np
import xpress as xp
import os, hashlib
xp.init("C:/Users/s2667242/AppData/Local/anaconda3/Lib/site-packages/xpress/license/xpauth.xpr")

# %%
# ——— 1. Parameter settings ———
tickers = [
    "AAPL","MSFT","GOOGL","AMZN","META","TSLA","JNJ","JPM","V","PG",
    "NVDA","DIS","UNH","HD","MA","PFE","BAC","KO","XOM","CVX"
]
start_date = "2020-01-01"
end_date   = "2025-07-24"

# ——— 2. Download price and volume data ———
data = yf.download(
    tickers,
    start=start_date,
    end=end_date,
    auto_adjust=False,
    progress=False
)

# ——— 3. Extract closing price and volume (note: Adj Close for profit; Close for USD volume) ———
prices_adj = data["Adj Close"]         # 用于收益
prices_raw = data["Close"]             # 未复权价，用于美元成交额
volumes    = data["Volume"]            # DataFrame (T×d)

# ——— 4. Calculate daily simple return, average return, and covariance ———
returns = prices_adj.pct_change().dropna()   # 用复权价
mean_daily_returns = returns.mean()          # Series, 长度 d
cov_matrix         = returns.cov()           # DataFrame d×d

print("Average daily income (top 5):")
print(mean_daily_returns.head())
print("\nDaily covariance matrix (first 3×3):")
print(cov_matrix.iloc[:3, :3])

# ——— 5. Daily volatility σ and ADV (average daily USD turnover) 
sigma_all  = returns.std(axis=0).values
# Upward and downward volatility (for γ±)
up_returns   = returns.clip(lower=0)
down_returns = (-returns).clip(lower=0)
sigma_plus   = up_returns.std(axis=0).values
sigma_minus  = down_returns.std(axis=0).values

#ADV: Daily USD turnover (unadjusted Close × Volume), aligned with returns
dollar_vol = (prices_raw.reindex_like(volumes) * volumes).loc[returns.index]
Vbar = dollar_vol.mean(axis=0).values     # shape=(d,)

# ===== Auxiliary functions: ILLIQ calibration, Gershgorin upper bound, delta inversion =====
def winsorize_ser(s: pd.Series, q=0.995):
    lo, hi = s.quantile(1-q), s.quantile(q)
    return s.clip(lower=lo, upper=hi)

def estimate_kappa_from_illiq(prices_raw: pd.DataFrame,
                              volumes: pd.DataFrame,
                              returns: pd.DataFrame,
                              sigma_vec, side="both"):
    """
    ILLIQ_t = |r_t| / DollarVol_t, DollarVol_t = raw_close_t * volume_t
    κ ≈ median(ILLIQ) * ADV$ / σ
    """
    px_raw = prices_raw.loc[returns.index]
    vol    = volumes.loc[returns.index]
    dollar_vol = (px_raw * vol).replace(0, np.nan)

    illiq = (returns.abs() / dollar_vol).replace([np.inf, -np.inf], np.nan)
    if side == "plus":
        mask = (returns > 0)
    elif side == "minus":
        mask = (returns < 0)
    else:
        mask = pd.DataFrame(True, index=returns.index, columns=returns.columns)

    illiq_med = illiq.where(mask).median(axis=0, skipna=True)
    illiq_med = winsorize_ser(illiq_med, q=0.995)

    # Here we use the average of daily US dollar trading volume as ADV$
    Vbar_local = (px_raw * vol).mean(axis=0)
    sigma = pd.Series(sigma_vec, index=returns.columns)

    kappa = (illiq_med * Vbar_local / sigma).replace([np.inf, -np.inf], np.nan)
    kappa = kappa.clip(lower=0.01, upper=100.0) 
    return kappa.values  # numpy

def gershgorin_delta_max(gamma: np.ndarray, corr: np.ndarray):
    G = np.sqrt(np.outer(gamma, gamma))
    A = np.abs(corr) * G
    row_sum_off = A.sum(axis=1) - np.diag(A)
    row_sum_off = np.where(row_sum_off <= 1e-12, np.inf, row_sum_off)
    return float(np.min(gamma / row_sum_off))

def delta_from_ratio(gamma: np.ndarray, corr: np.ndarray, rho=0.3, cap_ratio=0.9):
    G = np.sqrt(np.outer(gamma, gamma))
    A = np.abs(corr) * G
    row_sum_off = A.sum(axis=1) - np.diag(A)
    factor = row_sum_off / gamma
    mean_factor = np.mean(factor[np.isfinite(factor) & (factor > 0)])
    delta_star = rho / mean_factor if (mean_factor is not None and mean_factor > 0) else 0.0
    delta_max  = gershgorin_delta_max(gamma, corr)
    return float(min(delta_star, cap_ratio * delta_max)), float(delta_max)

# ——— 6. ILLIQ calibrates κ± and back-derives γ± (unit: 1/USD) ———
kappa_plus_hat  = estimate_kappa_from_illiq(prices_raw, volumes, returns, sigma_plus,  side="plus")
kappa_minus_hat = estimate_kappa_from_illiq(prices_raw, volumes, returns, sigma_minus, side="minus")

gamma_plus  = kappa_plus_hat  * sigma_plus  / Vbar
gamma_minus = kappa_minus_hat * sigma_minus / Vbar

print("kappa+:", np.round(kappa_plus_hat[:5], 6))
print("kappa-（:", np.round(kappa_minus_hat[:5], 6))
print("gamma+ :", np.median(gamma_plus), "  gamma- :", np.median(gamma_minus))

# ——— 7. Correlation coefficient matrix corr (as usual) ———
corr = cov_matrix.values / np.outer(sigma_all, sigma_all)

# ——— 8. Estimate δ ± (mean off/diag ratio + Gershgorin upper bound) ———
delta_plus,  delta_plus_max  = delta_from_ratio(gamma_plus,  corr, rho=0.3, cap_ratio=0.9)
delta_minus, delta_minus_max = delta_from_ratio(gamma_minus, corr, rho=0.3, cap_ratio=0.9)
print(f"[delta] +: {delta_plus:.6f} (max {delta_plus_max:.6f}) ; "
      f"-: {delta_minus:.6f} (max {delta_minus_max:.6f})")

# ——— 9. Construct Ω± and perform unified “bps calibration and scaling” ———
Gp = np.sqrt(np.outer(gamma_plus,  gamma_plus))
Gm = np.sqrt(np.outer(gamma_minus, gamma_minus))
Omega_plus  = np.diag(gamma_plus)  + delta_plus  * (Gp * corr)
Omega_minus = np.diag(gamma_minus) + delta_minus * (Gm * corr)

# ——Adjust the "transaction cost xi% ADV" to target_bps（）——
xi = 0.10         # 10% ADV 
target_bps = 100   # 
c = target_bps / 1e4

s_cand_p = 2*c / np.maximum(gamma_plus  * xi * Vbar, 1e-30)
s_cand_m = 2*c / np.maximum(gamma_minus * xi * Vbar, 1e-30)
s_omega  = float(np.median(np.concatenate([s_cand_p, s_cand_m])))

Omega_plus  = s_omega * Omega_plus
Omega_minus = s_omega * Omega_minus

print(f"[Ω scale] s_omega = {s_omega:.2e}  (xi={xi:.0%}, target={target_bps}bps)")

# —— SPD check—— #
eig_p = np.linalg.eigvalsh(Omega_plus)
eig_m = np.linalg.eigvalsh(Omega_minus)
print("[Ω SPD] min eig + / - :", eig_p.min(), eig_m.min())

=
# Out:
# 日度平均收益（前5）:
# Ticker
# AAPL    0.000984
# AMZN    0.000886
# BAC     0.000560
# CVX     0.000587
# DIS     0.000107
# dtype: float64
#
# 日度协方差矩阵（前3×3）:
# Ticker      AAPL      AMZN       BAC
# Ticker
# AAPL    0.000418  0.000279  0.000197
# AMZN    0.000279  0.000514  0.000159
# BAC     0.000197  0.000159  0.000495
# kappa+（前5）: [0.895093 0.970692 0.859875 0.811192 0.867407]
# kappa-（前5）: [0.895388 0.986045 0.824762 0.798702 0.89545 ]
# gamma+ 中位数: 5.7677360057231576e-12   gamma- 中位数: 5.55745404495135e-12
# [delta] +: 0.033721 (max 0.049720) ; -: 0.033875 (max 0.048921)
# [Ω scale] s_omega = 1.83e+01  (xi=10%, target=100bps)
# [Ω SPD] min eig + / - : 1.7493568348577572e-11 1.6385424997343952e-11

# %%
N = 10   # Number of users
d = 20   #Number of assets
# 1. 期望收益 mu_list
#Convert to NumPy array
mu_vec = mean_daily_returns.values  # shape = (20,)
mu_list = [mu_vec.copy() for _ in range(N)]

# 2.  Sigma_list
Sigma_mat = cov_matrix.values       # shape = (20,20)
Sigma_list = [Sigma_mat.copy() for _ in range(N)]

# 3. Annualized processing:
trading_days = 252
mu_annual   = mu_vec * trading_days          
Sigma_annual = Sigma_mat * trading_days      

mu_list   = [mu_annual.copy() for _ in range(N)]
Sigma_list = [Sigma_annual.copy() for _ in range(N)]

# %%
# ——— 3.Risk aversion coefficient γ_k (N(0,1) sampling truncated to [0,1], seed=42) ———
gamma_list = [
    0.49671415,  # γ₁
    0.64768854,  # γ₂
    0.76743473,  # γ₃
    0.54256004,  # γ₄
    0.24196227,  # γ₅
    0.31424733,  # γ₆
    0.06752820,  # γ₇
    0.11092259,  # γ₈
    0.37569802,  # γ₉
    0.82254491   # γ₁₀
]

# %%
budgets = [1e6, 5e5, 8e5, 1.2e6, 6e5, 9e5, 7e5, 4e5, 1.5e6, 1e6]

# %%
# === Unified calibration risk price theta_list===
alpha = 0.5  # Target: Average |Risk| ≈ 0.5 × Average |Revenue|
w_pct0 = np.full((N, d), 1.0/d)  

risk_proto = np.array([
    0.5 * gamma_list[n] * (budgets[n]**2) * (w_pct0[n] @ Sigma_list[n] @ w_pct0[n])
    for n in range(N)
])  

rev_est = np.array([
    budgets[n] * (mu_list[n] @ w_pct0[n])  
    for n in range(N)
])

eps = 1e-12
s = (alpha * max(rev_est.mean(), eps)) / max(risk_proto.mean(), eps)
theta_list = (s * np.array(gamma_list)).tolist()
print(f"[theta] s={s:.3e}; theta in [{min(theta_list):.2e}, {max(theta_list):.2e}] 1/USD/yr")
# Out:
# [theta] s=9.222e-06; theta in [6.23e-07, 7.59e-06] 1/USD/yr

# %%
# ----------Initial position----------

INIT_HOLDINGS_PATH = "initial_holdings.csv" 
INIT_SEED = 12345                            

def _dirichlet_like_from_hash(tickers, budgets, seed=INIT_SEED):
    
    N = len(budgets); d = len(tickers)
    W = np.zeros((N, d), dtype=float)
    for n in range(N):
        e = np.empty(d, dtype=float)
        for j, t in enumerate(tickers):
            key = f"{seed}|acct={n}|ticker={t}".encode()
            h = hashlib.sha256(key).digest()
            u64 = int.from_bytes(h[:8], "big")
            u = (u64 + 0.5) / 2**64         # map to (0,1)
            u = min(max(u, 1e-12), 1-1e-12) 
            e[j] = -np.log(u)               # Exp(1)
        w = e / e.sum()
        W[n, :] = w
    B = np.asarray(budgets, dtype=float)[:, None]
    return W * B  

def _load_or_make_initial_holdings(tickers, budgets, path=INIT_HOLDINGS_PATH, seed=INIT_SEED):
    if os.path.exists(path):
        df = pd.read_csv(path, index_col=0)
       
        ok_shape = (df.shape[0] == len(budgets)) and (df.shape[1] == len(tickers))
        ok_cols  = list(df.columns) == list(tickers)
        if ok_shape and ok_cols:
            return df.values
        else:
            print(f"[init] If the old file is found to have inconsistent shape or columns, regenerate and overwrite it：{path}")
    
    arr = _dirichlet_like_from_hash(tickers, budgets, seed=seed)
    df = pd.DataFrame(arr, index=[f"Acct {i}" for i in range(len(budgets))], columns=tickers)
    df.to_csv(path, float_format="%.6f")
    print(f"[init] The initial position has been generated and written：{path}")
    return arr


old_holdings = _load_or_make_initial_holdings(tickers, budgets)

# %%
# ——— Sector stock subscript ———
sector_idxs = {
    "T":  [tickers.index(t) for t in ["AAPL","MSFT","NVDA"]],                          # information Technology
    "C":  [tickers.index(t) for t in ["GOOGL","META","DIS"]],                          # Content and Entertainment
    "R":  [tickers.index(t) for t in ["AMZN","HD","TSLA"]],                            # Retail and Automotive
    "H":  [tickers.index(t) for t in ["JNJ","UNH","PFE"]],                             #medicalhealth
    "F":  [tickers.index(t) for t in ["JPM","BAC","V","MA"]],                          #financialservices
    "S":  [tickers.index(t) for t in ["PG","KO"]],                                     # Consumer staples
    "E":  [tickers.index(t) for t in ["XOM","CVX"]],                                   #energy
}

# %%
# ======= Cournot–Nash Best-Response MPO (sequential / simultaneous) =======

import numpy as np
import pandas as pd
import xpress as xp

# ----------  Personalized constraints for each household ----------
def add_user_constraints(model, n, w_vars, budgets, sector_idxs, tickers):
    b = budgets[n]
    if n == 0:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["H"]) >=  b*0.40)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]+sector_idxs["R"]) <=  b*0.25)
    elif n == 1:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]) >=  b*0.40)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["C"] + [tickers.index("AMZN")]) >=  b*0.30)
    elif n == 2:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]) >=  b*0.10)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]) <=  b*0.25)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["C"]) >=  b*0.10)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["C"]) <=  b*0.25)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["H"]) >=  b*0.10)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["H"]) <=  b*0.25)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["F"]) >=  b*0.10)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["F"]) <=  b*0.25)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["E"]) >= b*0.05)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["E"]) <= b*0.15)
    elif n == 3:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["F"]+sector_idxs["E"]) >= b*0.50)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["F"]) >=  b*0.20)
    elif n == 4:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["E"]) >=  b*0.15)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["F"]) >=  b*0.25)
    elif n == 5:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]) >=  b*0.30)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["H"]) >=  b*0.20)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["R"]) <=  b*0.15)
    elif n == 6:
        growth6 = sector_idxs["T"] + sector_idxs["C"] + sector_idxs["R"]
        model.addConstraint(xp.Sum(w_vars[j] for j in growth6) <= b*0.35)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["E"]+sector_idxs["F"]+sector_idxs["S"]) >= b*0.40)
    elif n == 7:
        model.addConstraint(xp.Sum(w_vars[j] for j in [tickers.index("AMZN"), tickers.index("TSLA")]) >= b*0.30)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]+sector_idxs["F"]+sector_idxs["H"]) <= b*0.50)
    elif n == 8:
        growth8 = [tickers.index(t) for t in ["NVDA","TSLA","AAPL","MSFT"]]
        model.addConstraint(xp.Sum(w_vars[j] for j in growth8) >= b*0.50)
    elif n == 9:
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["S"]+sector_idxs["E"]) >= b*0.20)
        model.addConstraint(xp.Sum(w_vars[j] for j in sector_idxs["T"]+sector_idxs["C"]+sector_idxs["R"]) >= b*0.30)

# ---------- Household optimal response subproblem----------
def solve_best_response(n, Wp_other, Wm_other,
                        mu_list, Sigma_list, theta_list,
                        budgets, Omega_plus, Omega_minus,
                        old_holdings, trading_days):
    d = len(mu_list[0])
    Bn = budgets[n]
    mu_n = mu_list[n]
    Sig_n = Sigma_list[n]
    theta_n = theta_list[n]

    m = xp.problem()

    # Variable (nth household)
    w   = [m.addVariable(lb=0.0, ub=Bn)   for j in range(d)]
    wp  = [m.addVariable(lb=0.0, ub=Bn)   for j in range(d)]
    wm  = [m.addVariable(lb=0.0, ub=Bn)   for j in range(d)]
    wpc = [m.addVariable(lb=0.0, ub=1.0)  for j in range(d)]

    # Linearization: wp - wm = w - old
    for j in range(d):
        m.addConstraint(wp[j] - wm[j] == w[j] - old_holdings[n, j])

    # Full Position (USD & Weight)
    m.addConstraint(xp.Sum(w[j] for j in range(d)) == Bn)
    m.addConstraint(xp.Sum(wpc[j] for j in range(d)) == 1)
    for j in range(d):
        m.addConstraint(w[j] == Bn * wpc[j])

    # Personalized constraints
    add_user_constraints(m, n, w, budgets, sector_idxs, tickers)

    # Target: Revenue + RiskPenalty - ImpactCost (NE caliber)
    lin  = xp.Sum(mu_n[j] * w[j] for j in range(d))
    risk = -0.5 * theta_n * (Bn**2) * xp.Sum(Sig_n[i][j] * wpc[i] * wpc[j]
                                             for i in range(d) for j in range(d))

    # Cost: b_n^T Ω (b_other + b_n) + s_n^T Ω (s_other + s_n); annualized multiplication by trading_days
    cost_p = - trading_days * (
        xp.Sum(Omega_plus[i, j]  * wp[i] * (Wp_other[j] + wp[j]) for i in range(d) for j in range(d))
    )
    cost_m = - trading_days * (
        xp.Sum(Omega_minus[i, j] * wm[i] * (Wm_other[j] + wm[j]) for i in range(d) for j in range(d))
    )

    m.setObjective(lin + risk + cost_p + cost_m, sense=xp.maximize)
    m.solve()

    w_sol  = np.array([m.getSolution(w[j])  for j in range(d)], dtype=float)
    wp_sol = np.array([m.getSolution(wp[j]) for j in range(d)], dtype=float)
    wm_sol = np.array([m.getSolution(wm[j]) for j in range(d)], dtype=float)
    return w_sol, wp_sol, wm_sol

# ---------- Outer iteration: sequential / simultaneous ----------
N = len(budgets)
d = len(tickers)
trading_days = 252

# Initial value: use old_holdings (zero transactions)
w_cur  = old_holdings.copy()
wp_cur = np.zeros_like(w_cur)
wm_cur = np.zeros_like(w_cur)

# Iteration settings
max_iter = 200
tol = 1e-6               
mode = "sequential"      

for q in range(max_iter):
    w_prev = w_cur.copy()

    if mode == "sequential":
        for n in range(N):
            Wp_other = wp_cur.sum(axis=0) - wp_cur[n]
            Wm_other = wm_cur.sum(axis=0) - wm_cur[n]
            w_n, wp_n, wm_n = solve_best_response(
                n, Wp_other, Wm_other,
                mu_list, Sigma_list, theta_list,
                budgets, Omega_plus, Omega_minus,
                old_holdings, trading_days
            )
            w_cur[n]  = w_n
            wp_cur[n] = wp_n
            wm_cur[n] = wm_n

    else:  
        w_new  = np.zeros_like(w_cur)
        wp_new = np.zeros_like(wp_cur)
        wm_new = np.zeros_like(wm_cur)
        Wp_tot = wp_cur.sum(axis=0)
        Wm_tot = wm_cur.sum(axis=0)
        for n in range(N):
            Wp_other = Wp_tot - wp_cur[n]
            Wm_other = Wm_tot - wm_cur[n]
            w_n, wp_n, wm_n = solve_best_response(
                n, Wp_other, Wm_other,
                mu_list, Sigma_list, theta_list,
                budgets, Omega_plus, Omega_minus,
                old_holdings, trading_days
            )
            w_new[n], wp_new[n], wm_new[n] = w_n, wp_n, wm_n

        
        alpha = 1.0 / N
        w_cur = (1 - alpha) * w_cur + alpha * w_new
        delta = w_cur - old_holdings
        wp_cur = np.maximum(delta, 0.0)
        wm_cur = np.maximum(-delta, 0.0)

    # Convergence criterion
    rel = np.max([np.max(np.abs(w_cur[n] - w_prev[n])) / max(budgets[n], 1.0) for n in range(N)])
    print(f"[iter {q:03d}] max_rel_change={rel:.3e}")
    if rel < tol:
        print(f"Converged at iter {q}")
        break

# ---------- Results measurement and export----------
bud_arr = np.asarray(budgets, dtype=float)
w_pct   = w_cur / bud_arr[:, None]
theta   = np.asarray(theta_list, dtype=float)

# Benefit/risk/cost/utility per household (NE caliber)
revenues = np.array([mu_list[n] @ w_cur[n] for n in range(N)])
risk_pen = np.array([
    -0.5 * theta[n] * (bud_arr[n]**2) * (w_pct[n] @ Sigma_list[n] @ w_pct[n]) for n in range(N)
])
Wp_tot = wp_cur.sum(axis=0)
Wm_tot = wm_cur.sum(axis=0)
daily_cost = 0.5 * (Wp_tot @ Omega_plus @ Wp_tot + Wm_tot @ Omega_minus @ Wm_tot)  # pooled cost
annual_cost = trading_days * daily_cost

# NE Cost per household: b_n^T Ω Wp_tot + s_n^T Ω Wm_tot (consistent with NE objective)
cost_each = trading_days * (np.array([wp_cur[n] @ Omega_plus @ Wp_tot for n in range(N)]) +
                            np.array([wm_cur[n] @ Omega_minus @ Wm_tot for n in range(N)]))
u_nash = revenues + risk_pen - cost_each

# Consistency check
chk_total = cost_each.sum()
print(f"[CHECK] annual pooled cost (1x) = {trading_days*(Wp_tot @ Omega_plus @ Wp_tot + Wm_tot @ Omega_minus @ Wm_tot):,.2f}")
print(f"[CHECK] sum(cost_each)         = {chk_total:,.2f}")

#Export
acct_idx = [f"Acct {i}" for i in range(N)]
pd.DataFrame(w_cur, index=acct_idx, columns=tickers).to_csv("nash_holdings_dollar.csv", float_format="%.6f")
pd.DataFrame(w_pct, index=acct_idx, columns=tickers).to_csv("nash_holdings_weight.csv", float_format="%.6f")
pd.DataFrame({
    "Revenue": revenues,
    "RiskPenalty": risk_pen,
    "ImpactCost": -cost_each,    
    "Utility_NE": u_nash
}, index=acct_idx).to_csv("nash_components.csv", float_format="%.6f")

with open("nash_total_cost.txt", "w") as f:
    f.write(f"{annual_cost:.6f}")

print("✔  nash_holdings_dollar.csv, nash_holdings_weight.csv, nash_components.csv, nash_total_cost.txt")
# Out:
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 85KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 85KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.92e+03,  1.00e+06]
#   Objective      [min,max] : [ 1.31e-02,  7.54e-01] / [ 1.31e-02,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  2.11e+06] / [ 1.00e-09,  2.11e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   7.90e+05   1.62e+00   3.29e+03  -2.4961680e+05   8.4386565e+07   8.6e+07
#    1   9.67e+03   1.98e-02   4.02e+01  -1.4934120e+05   1.8877717e+06   2.1e+06
#    2   1.37e+03   2.81e-03   5.69e+00   5.5778809e+04   5.9827548e+05   5.4e+05
#    3   9.10e-08   2.05e-16   1.16e-10   1.7744774e+05   3.0704405e+05   1.3e+05
#    4   8.73e-11   1.52e-16   1.16e-10   2.0343714e+05   2.1588675e+05   1.2e+04
#    5   1.16e-10   1.39e-16   1.16e-10   2.0755856e+05   2.0836759e+05   8.1e+02
#    6   1.16e-10   1.39e-16   1.16e-10   2.0793362e+05   2.0800541e+05   7.2e+01
#    7   4.37e-11   1.15e-16   1.16e-10   2.0796653e+05   2.0797241e+05   5.9e+00
#    8   2.03e-11   1.41e-16   1.16e-10   2.0796910e+05   2.0796944e+05   3.4e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 2.078853582951798e+05
#   Max primal violation      (abs/rel) : 2.910e-11 / 1.455e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.885e+04 / 1.614e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 87KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          147 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           87 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 87KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  5.00e+05] / [ 8.24e+01,  5.00e+05]
#   Objective      [min,max] : [ 4.14e-05,  7.54e-01] / [ 4.14e-05,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  6.89e+05] / [ 1.00e-09,  2.76e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1205   Flops:        22540
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.11e+06   1.51e+00   6.97e+04  -1.1785186e+05   4.6620638e+07   4.8e+07
#    1   1.27e-06   2.30e-02   5.82e-11  -8.2647868e+03   1.1173543e+06   1.1e+06
#    2   1.19e-07   2.17e-03   5.82e-11   5.2565342e+04   2.6040965e+05   2.1e+05
#    3   6.18e-11   2.13e-16   5.82e-11   1.0384747e+05   1.3720630e+05   3.3e+04
#    4   3.27e-11   1.22e-16   5.82e-11   1.1411014e+05   1.1642356e+05   2.3e+03
#    5   3.03e-11   1.15e-16   5.82e-11   1.1518500e+05   1.1537881e+05   1.9e+02
#    6   5.82e-11   1.56e-16   5.82e-11   1.1526282e+05   1.1528088e+05   1.8e+01
#    7   9.63e-11   1.76e-16   5.82e-11   1.1526974e+05   1.1527075e+05   1.0e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.152076320621375e+05
#   Max primal violation      (abs/rel) : 9.631e-11 / 9.631e-11
#   Max dual violation        (abs/rel) : 3.692e-12 / 7.385e-18
#   Max complementarity viol. (abs/rel) : 2.884e+04 / 1.602e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 90KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         52 rows           80 cols          174 elements
#       1200 qobjelem
# Presolved problem has:
#         26 rows           60 cols           97 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 458KB (peak 481KB, 90KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  8.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  8.00e+05] / [ 4.67e+02,  8.00e+05]
#   Objective      [min,max] : [ 1.26e-04,  7.54e-01] / [ 1.26e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  2.09e+06] / [ 1.00e-09,  3.27e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1317   Flops:        26308
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.61e+06   1.00e+00   2.11e+05  -7.2776267e+05   4.6323538e+07   4.9e+07
#    1   8.77e+03   5.46e-03   1.15e+03  -1.0995707e+05   1.4083134e+06   1.5e+06
#    2   2.30e+02   1.43e-04   3.01e+01   5.3285238e+04   2.3357792e+05   1.8e+05
#    3   1.49e+01   9.31e-06   1.96e+00   1.1401637e+05   1.4661152e+05   3.3e+04
#    4   4.06e-02   2.53e-08   5.32e-03   1.2801524e+05   1.3079405e+05   2.8e+03
#    5   7.49e-04   4.68e-10   9.81e-05   1.2935300e+05   1.2954925e+05   2.0e+02
#    6   6.02e-05   3.76e-11   7.88e-06   1.2943781e+05   1.2946066e+05   2.3e+01
#    7   9.80e-07   5.91e-13   1.28e-07   1.2944352e+05   1.2944474e+05   1.2e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.293936826817346e+05
#   Max primal violation      (abs/rel) : 9.795e-07 / 9.795e-07
#   Max dual violation        (abs/rel) : 3.749e-07 / 3.749e-07
#   Max complementarity viol. (abs/rel) : 3.020e+04 / 1.080e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 92KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          152 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           92 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 92KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.20e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.20e+06] / [ 6.44e+02,  1.20e+06]
#   Objective      [min,max] : [ 1.62e-04,  7.54e-01] / [ 1.62e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.33e+06] / [ 1.00e-09,  2.31e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1186   Flops:        21506
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.78e+05   1.27e+00   1.21e+05   5.5917061e+04   9.2337746e+07   9.6e+07
#    1   7.21e-07   1.26e-01   2.33e-10   7.8461964e+04   1.4763896e+07   1.5e+07
#    2   5.12e-08   8.97e-03   2.33e-10   1.1716173e+05   1.4483093e+06   1.3e+06
#    3   2.76e-10   2.05e-16   2.33e-10   1.6685009e+05   3.0355689e+05   1.4e+05
#    4   2.76e-10   1.20e-16   2.33e-10   1.9291530e+05   2.0390081e+05   1.1e+04
#    5   1.75e-10   1.32e-16   2.33e-10   1.9672639e+05   1.9718746e+05   4.6e+02
#    6   1.75e-10   1.55e-16   2.33e-10   1.9692170e+05   1.9696117e+05   3.9e+01
#    7   1.46e-10   1.13e-16   2.33e-10   1.9693589e+05   1.9693807e+05   2.2e+00
#    8   2.04e-10   1.62e-16   2.33e-10   1.9693675e+05   1.9693678e+05   3.0e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.968239222496235e+05
#   Max primal violation      (abs/rel) : 2.037e-10 / 2.037e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 6.275e+04 / 1.381e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 94KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          146 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           86 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 94KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  6.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  6.00e+05] / [ 5.17e+03,  6.00e+05]
#   Objective      [min,max] : [ 2.54e-04,  7.54e-01] / [ 2.54e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.71e+05] / [ 1.00e-09,  1.03e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1178   Flops:        21082
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   5.08e+04   1.64e+00   5.72e+03  -1.8945940e+04   6.1058000e+07   6.1e+07
#    1   8.73e-07   1.33e-15   1.16e-10  -4.6752364e+03   2.0251548e+06   2.0e+06
#    2   9.14e-09   2.36e-16   1.16e-10   1.6750812e+05   5.3297294e+05   3.7e+05
#    3   8.73e-11   1.78e-16   1.16e-10   2.8509644e+05   3.2230351e+05   3.7e+04
#    4   5.82e-11   1.92e-16   1.16e-10   3.0059492e+05   3.0337985e+05   2.8e+03
#    5   1.75e-10   1.98e-16   1.16e-10   3.0211454e+05   3.0234295e+05   2.3e+02
#    6   1.31e-10   2.04e-16   1.16e-10   3.0218549e+05   3.0218877e+05   3.3e+00
#    7   2.76e-10   2.14e-16   1.16e-10   3.0218660e+05   3.0218661e+05   3.9e-03
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 3.021297307376249e+05
#   Max primal violation      (abs/rel) : 2.765e-10 / 2.765e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 1.593e+04 / 4.424e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 97KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         45 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         24 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 97KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  9.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  9.00e+05] / [ 4.53e+02,  9.00e+05]
#   Objective      [min,max] : [ 3.14e-04,  7.54e-01] / [ 3.14e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.08e+06] / [ 1.00e-09,  1.34e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1256   Flops:        24614
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.51e+05   1.91e+00   2.13e+04  -1.3538121e+05   8.0609820e+07   8.3e+07
#    1   4.49e+05   9.00e-01   1.01e+04  -1.1728739e+05   3.8528789e+07   4.0e+07
#    2   2.35e+04   4.71e-02   5.27e+02  -1.0338383e+05   2.3597653e+06   2.5e+06
#    3   5.85e-08   2.22e-16   1.16e-10   9.8225112e+04   6.4512848e+05   5.5e+05
#    4   1.15e-09   1.94e-16   1.16e-10   2.0580848e+05   3.1308578e+05   1.1e+05
#    5   1.55e-10   1.67e-16   1.16e-10   2.3342043e+05   2.4413608e+05   1.1e+04
#    6   1.16e-10   8.79e-17   1.16e-10   2.3803875e+05   2.3895475e+05   9.2e+02
#    7   1.02e-10   1.61e-16   1.16e-10   2.3833494e+05   2.3839406e+05   5.9e+01
#    8   1.60e-10   7.28e-17   1.16e-10   2.3835073e+05   2.3835177e+05   1.0e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.382639239204454e+05
#   Max primal violation      (abs/rel) : 5.093e-11 / 5.093e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.289e+04 / 1.527e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 99KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          157 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           97 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 99KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  7.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  7.00e+05] / [ 3.09e+03,  7.00e+05]
#   Objective      [min,max] : [ 3.77e-04,  7.54e-01] / [ 3.77e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.41e+05] / [ 1.00e-09,  2.87e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   3.46e+05   2.44e+00   0.00e+00   2.4169771e+03   6.3146897e+07   6.5e+07
#    1   1.92e+05   1.35e+00   1.16e-10  -1.3218571e+04   3.5357485e+07   3.6e+07
#    2   1.76e+04   1.24e-01   1.16e-10   4.9870019e+03   3.9101040e+06   4.0e+06
#    3   2.14e+02   9.63e-04   1.16e-10   2.7230577e+05   1.1473920e+06   8.8e+05
#    4   3.42e+00   1.03e-05   1.16e-10   3.9836960e+05   4.6710091e+05   6.9e+04
#    5   1.94e-10   3.33e-16   1.16e-10   4.3131412e+05   4.3787730e+05   6.6e+03
#    6   1.61e-10   3.33e-16   1.16e-10   4.3501248e+05   4.3551322e+05   5.0e+02
#    7   1.16e-10   2.22e-16   1.16e-10   4.3514103e+05   4.3514924e+05   8.2e+00
#    8   1.83e-10   3.33e-16   1.16e-10   4.3514539e+05   4.3514539e+05   8.3e-03
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 4.350748974525592e+05
#   Max primal violation      (abs/rel) : 6.661e-11 / 6.661e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 1.234e+04 / 2.712e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 101KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          152 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           92 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 101KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  4.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+05] / [ 2.91e+02,  4.00e+05]
#   Objective      [min,max] : [ 4.39e-04,  7.54e-01] / [ 4.39e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  7.55e+04] / [ 1.00e-09,  4.72e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1195   Flops:        21990
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.81e+05   2.33e+00   0.00e+00   4.6959752e+04   3.5182185e+07   3.6e+07
#    1   1.41e+05   1.17e+00   5.82e-11   2.8999837e+04   1.7974836e+07   1.8e+07
#    2   1.98e+04   1.64e-01   5.82e-11   3.0594590e+04   2.7262489e+06   2.7e+06
#    3   4.11e+02   4.78e-04   5.82e-11   1.0226948e+05   6.7206890e+05   5.7e+05
#    4   7.00e+00   5.97e-06   5.82e-11   1.8790820e+05   2.4225752e+05   5.4e+04
#    5   4.84e-02   2.92e-08   5.82e-11   2.1425520e+05   2.1877987e+05   4.5e+03
#    6   1.55e-03   8.90e-10   5.82e-11   2.1664364e+05   2.1697438e+05   3.3e+02
#    7   1.84e-05   1.03e-11   5.82e-11   2.1673951e+05   2.1674655e+05   7.0e+00
#    8   6.47e-10   3.33e-16   5.82e-11   2.1674273e+05   2.1674281e+05   7.6e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.167095495286733e+05
#   Max primal violation      (abs/rel) : 6.377e-10 / 6.377e-10
#   Max dual violation        (abs/rel) : 7.315e-14 / 1.829e-19
#   Max complementarity viol. (abs/rel) : 3.623e+03 / 1.294e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 104KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         43 rows           80 cols          144 elements
#       1200 qobjelem
# Presolved problem has:
#         22 rows           60 cols           84 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 103KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.50e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.50e+06] / [ 5.67e+03,  1.50e+06]
#   Objective      [min,max] : [ 4.99e-04,  7.54e-01] / [ 4.99e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.60e+06] / [ 1.00e-09,  1.60e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1171   Flops:        21484
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.95e+06   1.31e+00   3.32e+05  -8.5695077e+05   1.2090330e+08   1.4e+08
#    1   1.00e-06   3.78e-03   2.33e-10   1.2187019e+04   6.2580575e+06   6.2e+06
#    2   1.39e-07   5.24e-04   2.33e-10   6.9880605e+04   1.0812709e+06   1.0e+06
#    3   6.55e-10   3.30e-16   2.33e-10   1.4895572e+05   3.5763205e+05   2.1e+05
#    4   2.18e-10   1.77e-16   2.33e-10   1.9001424e+05   2.0935824e+05   1.9e+04
#    5   5.82e-11   1.39e-16   2.33e-10   1.9625882e+05   1.9793674e+05   1.7e+03
#    6   5.82e-11   1.29e-16   2.33e-10   1.9674401e+05   1.9687329e+05   1.3e+02
#    7   1.16e-10   1.54e-16   2.33e-10   1.9678697e+05   1.9678951e+05   2.5e+00
#    8   1.46e-10   1.41e-16   2.33e-10   1.9678767e+05   1.9678776e+05   9.1e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.966070856279311e+05
#   Max primal violation      (abs/rel) : 1.455e-10 / 1.455e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 8.898e+04 / 1.880e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 106KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          153 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           93 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 106KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.39e+02,  1.00e+06]
#   Objective      [min,max] : [ 6.60e-04,  7.54e-01] / [ 6.60e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.50e+06] / [ 1.00e-09,  3.50e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.68e-10   1.00e+03   0.00e+00  -3.6363446e+05   6.0000657e+10   6.0e+10
#    1   1.09e-10   1.25e+00   1.16e-10  -3.6358883e+05   7.4545764e+07   7.5e+07
#    2   8.00e-11   1.12e-01   1.16e-10  -3.2303834e+05   6.7859847e+06   7.1e+06
#    3   7.28e-11   1.94e-16   1.16e-10  -1.4319210e+05   8.0027955e+05   9.4e+05
#    4   1.16e-10   2.06e-16   1.16e-10   4.5504520e+04   1.6230733e+05   1.2e+05
#    5   2.33e-10   1.64e-16   1.16e-10   9.8549085e+04   1.1082637e+05   1.2e+04
#    6   5.82e-11   1.77e-16   1.16e-10   1.0435539e+05   1.0532623e+05   9.7e+02
#    7   1.10e-10   1.53e-16   1.16e-10   1.0464357e+05   1.0468045e+05   3.7e+01
#    8   1.60e-10   1.85e-16   1.16e-10   1.0465555e+05   1.0465605e+05   5.0e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.046001461114088e+05
#   Max primal violation      (abs/rel) : 1.601e-10 / 1.601e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.704e+04 / 1.094e-01
# [iter 000] max_rel_change=6.983e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 108KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 108KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.92e+03,  1.00e+06]
#   Objective      [min,max] : [ 6.59e-04,  7.54e-01] / [ 6.59e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  2.11e+06] / [ 1.00e-09,  2.11e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   7.90e+05   1.62e+00   3.29e+03  -3.7208299e+05   8.4386565e+07   8.6e+07
#    1   8.91e+03   1.83e-02   3.71e+01  -2.6684366e+05   1.7142548e+06   2.0e+06
#    2   1.27e+03   2.58e-03   5.27e+00   1.4546164e+04   5.4031017e+05   5.3e+05
#    3   9.19e-08   1.67e-16   1.16e-10   1.6071190e+05   2.8209865e+05   1.2e+05
#    4   3.11e-09   2.50e-16   1.16e-10   1.9137796e+05   2.0458876e+05   1.3e+04
#    5   2.04e-10   1.39e-16   1.16e-10   1.9595918e+05   1.9702487e+05   1.1e+03
#    6   7.47e-11   2.99e-16   1.16e-10   1.9626830e+05   1.9633296e+05   6.5e+01
#    7   8.73e-11   1.67e-16   1.16e-10   1.9628844e+05   1.9628958e+05   1.1e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.962286137898404e+05
#   Max primal violation      (abs/rel) : 3.274e-11 / 3.274e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.546e+04 / 1.494e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 110KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          147 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           87 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 110KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  5.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  5.00e+05] / [ 8.24e+01,  5.00e+05]
#   Objective      [min,max] : [ 6.36e-04,  7.54e-01] / [ 6.36e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  6.89e+05] / [ 1.00e-09,  2.76e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1205   Flops:        22540
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.11e+06   1.51e+00   6.97e+04  -1.7336857e+05   4.6620638e+07   4.8e+07
#    1   1.27e-06   2.21e-02   5.82e-11  -6.2292040e+04   1.0553967e+06   1.1e+06
#    2   1.24e-07   2.16e-03   5.82e-11   3.0923815e+04   2.4337098e+05   2.1e+05
#    3   1.05e-10   1.85e-16   5.82e-11   9.7492595e+04   1.2729229e+05   3.0e+04
#    4   2.91e-11   8.37e-17   5.82e-11   1.0854584e+05   1.1068982e+05   2.1e+03
#    5   7.36e-11   1.07e-16   5.82e-11   1.0924747e+05   1.0940747e+05   1.6e+02
#    6   9.46e-11   1.79e-16   5.82e-11   1.0929399e+05   1.0929754e+05   3.5e+00
#    7   7.87e-11   2.23e-16   5.82e-11   1.0929476e+05   1.0929486e+05   9.8e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.092355395449138e+05
#   Max primal violation      (abs/rel) : 7.871e-11 / 7.871e-11
#   Max dual violation        (abs/rel) : 4.076e-12 / 8.152e-18
#   Max complementarity viol. (abs/rel) : 2.811e+04 / 1.633e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 113KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         52 rows           80 cols          174 elements
#       1200 qobjelem
# Presolved problem has:
#         26 rows           60 cols           97 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 458KB (peak 481KB, 113KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  8.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  8.00e+05] / [ 4.67e+02,  8.00e+05]
#   Objective      [min,max] : [ 6.52e-04,  7.54e-01] / [ 6.52e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  2.09e+06] / [ 1.00e-09,  3.27e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1317   Flops:        26308
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.61e+06   1.00e+00   2.11e+05  -8.0785295e+05   4.6323538e+07   4.9e+07
#    1   1.02e+04   6.37e-03   1.34e+03  -1.8499852e+05   1.4035574e+06   1.6e+06
#    2   2.98e+02   1.85e-04   3.90e+01   2.9822774e+04   2.3470182e+05   2.0e+05
#    3   1.75e+01   1.09e-05   2.29e+00   1.0484281e+05   1.4078608e+05   3.6e+04
#    4   5.09e-01   3.54e-07   6.66e-02   1.2119536e+05   1.2452527e+05   3.3e+03
#    5   3.31e-02   2.31e-08   4.34e-03   1.2247828e+05   1.2278860e+05   3.1e+02
#    6   1.46e-03   9.44e-10   1.91e-04   1.2257411e+05   1.2260151e+05   2.7e+01
#    7   2.57e-06   1.59e-12   3.36e-07   1.2258619e+05   1.2258630e+05   1.1e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.225432157986675e+05
#   Max primal violation      (abs/rel) : 2.567e-06 / 2.567e-06
#   Max dual violation        (abs/rel) : 6.638e-08 / 6.638e-08
#   Max complementarity viol. (abs/rel) : 2.946e+04 / 1.056e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 115KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          152 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           92 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 115KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.20e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.20e+06] / [ 6.44e+02,  1.20e+06]
#   Objective      [min,max] : [ 6.39e-04,  7.54e-01] / [ 6.39e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.33e+06] / [ 1.00e-09,  2.31e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1186   Flops:        21506
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.78e+05   1.27e+00   1.21e+05   4.6401260e+04   9.2330850e+07   9.6e+07
#    1   7.01e-07   1.26e-01   2.33e-10   6.2949111e+04   1.4680428e+07   1.5e+07
#    2   4.82e-08   8.71e-03   2.33e-10   1.0145030e+05   1.3792062e+06   1.3e+06
#    3   4.37e-10   1.65e-16   2.33e-10   1.5599632e+05   2.8273119e+05   1.3e+05
#    4   5.82e-11   1.14e-16   2.33e-10   1.8422009e+05   1.9729233e+05   1.3e+04
#    5   1.75e-10   1.49e-16   2.33e-10   1.8817424e+05   1.8882828e+05   6.5e+02
#    6   8.73e-11   1.23e-16   2.33e-10   1.8839134e+05   1.8841757e+05   2.6e+01
#    7   2.04e-10   2.97e-16   2.33e-10   1.8840016e+05   1.8840021e+05   4.6e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.882897121598522e+05
#   Max primal violation      (abs/rel) : 2.037e-10 / 2.037e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 6.259e+04 / 1.387e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 117KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          146 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           86 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 117KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  6.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  6.00e+05] / [ 5.17e+03,  6.00e+05]
#   Objective      [min,max] : [ 6.44e-04,  7.54e-01] / [ 6.44e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.71e+05] / [ 1.00e-09,  1.03e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1178   Flops:        21082
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   5.08e+04   1.64e+00   5.72e+03  -5.9572678e+04   6.1058000e+07   6.1e+07
#    1   8.77e-07   3.89e-16   1.16e-10  -4.4319591e+04   1.9942328e+06   2.0e+06
#    2   2.58e-08   4.16e-16   1.16e-10   1.4337629e+05   5.3335749e+05   3.9e+05
#    3   1.46e-10   2.09e-16   1.16e-10   2.7657238e+05   3.1603299e+05   3.9e+04
#    4   5.82e-11   2.23e-16   1.16e-10   2.9557905e+05   2.9796646e+05   2.4e+03
#    5   2.76e-10   1.50e-16   1.16e-10   2.9648796e+05   2.9663403e+05   1.5e+02
#    6   2.91e-11   1.73e-16   1.16e-10   2.9653237e+05   2.9653278e+05   4.1e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   6 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 2.964754862434138e+05
#   Max primal violation      (abs/rel) : 2.910e-11 / 2.473e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 1.593e+04 / 4.424e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 120KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         45 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         24 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 120KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  9.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  9.00e+05] / [ 4.53e+02,  9.00e+05]
#   Objective      [min,max] : [ 6.40e-04,  7.54e-01] / [ 6.40e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.08e+06] / [ 1.00e-09,  1.34e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1256   Flops:        24614
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.51e+05   1.91e+00   2.13e+04  -1.8356378e+05   8.0609820e+07   8.3e+07
#    1   4.40e+05   8.82e-01   9.87e+03  -1.6482756e+05   3.7776743e+07   3.9e+07
#    2   2.43e+04   4.87e-02   5.45e+02  -1.4619347e+05   2.4043491e+06   2.6e+06
#    3   5.15e-08   4.44e-16   1.16e-10   7.7061648e+04   6.4425741e+05   5.7e+05
#    4   1.34e-09   1.67e-16   1.16e-10   1.9841107e+05   3.0730320e+05   1.1e+05
#    5   9.82e-11   2.22e-16   1.16e-10   2.2843669e+05   2.4062099e+05   1.2e+04
#    6   1.09e-10   1.67e-16   1.16e-10   2.3306050e+05   2.3412774e+05   1.1e+03
#    7   1.09e-10   1.67e-16   1.16e-10   2.3333620e+05   2.3337844e+05   4.2e+01
#    8   5.09e-11   1.11e-16   1.16e-10   2.3335178e+05   2.3335193e+05   1.4e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.332739434445067e+05
#   Max primal violation      (abs/rel) : 8.004e-11 / 8.004e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.124e+04 / 1.471e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 122KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          157 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           97 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 122KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  7.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  7.00e+05] / [ 3.09e+03,  7.00e+05]
#   Objective      [min,max] : [ 6.37e-04,  7.54e-01] / [ 6.37e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.41e+05] / [ 1.00e-09,  2.87e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   3.46e+05   2.44e+00   0.00e+00  -2.6879220e+04   6.3146897e+07   6.5e+07
#    1   1.92e+05   1.35e+00   1.16e-10  -4.2129537e+04   3.5341786e+07   3.6e+07
#    2   1.77e+04   1.25e-01   1.16e-10  -2.2526398e+04   3.9072169e+06   4.0e+06
#    3   2.28e-07   2.22e-16   1.16e-10   2.5506708e+05   1.1312755e+06   8.8e+05
#    4   3.50e-09   2.22e-16   1.16e-10   3.9190690e+05   4.6218689e+05   7.0e+04
#    5   1.06e-10   2.32e-16   1.16e-10   4.2862087e+05   4.3447599e+05   5.9e+03
#    6   8.73e-11   2.22e-16   1.16e-10   4.3160203e+05   4.3201533e+05   4.1e+02
#    7   8.26e-11   1.67e-16   1.16e-10   4.3166563e+05   4.3166881e+05   3.2e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 4.315950816798783e+05
#   Max primal violation      (abs/rel) : 8.255e-11 / 8.255e-11
#   Max dual violation        (abs/rel) : 4.896e-13 / 6.994e-19
#   Max complementarity viol. (abs/rel) : 1.234e+04 / 2.712e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 124KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          152 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           92 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 124KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  4.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+05] / [ 2.91e+02,  4.00e+05]
#   Objective      [min,max] : [ 6.39e-04,  7.54e-01] / [ 6.39e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  7.55e+04] / [ 1.00e-09,  4.72e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1195   Flops:        21990
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.81e+05   2.33e+00   0.00e+00   3.3415500e+04   3.5182185e+07   3.6e+07
#    1   1.41e+05   1.17e+00   5.82e-11   1.5573730e+04   1.7966332e+07   1.8e+07
#    2   1.97e+04   1.64e-01   0.00e+00   1.7522978e+04   2.7140417e+06   2.7e+06
#    3   3.92e+02   4.58e-04   5.82e-11   9.1914244e+04   6.6205940e+05   5.7e+05
#    4   7.18e+00   6.14e-06   5.82e-11   1.8389316e+05   2.3970050e+05   5.6e+04
#    5   1.56e-01   9.50e-08   5.82e-11   2.1214575e+05   2.1685461e+05   4.7e+03
#    6   5.60e-03   3.23e-09   5.82e-11   2.1434015e+05   2.1468596e+05   3.5e+02
#    7   8.71e-05   5.23e-11   5.82e-11   2.1444067e+05   2.1444841e+05   7.7e+00
#    8   2.79e-08   1.68e-14   5.82e-11   2.1444397e+05   2.1444404e+05   6.6e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.144107876954437e+05
#   Max primal violation      (abs/rel) : 2.787e-08 / 2.787e-08
#   Max dual violation        (abs/rel) : 2.662e-13 / 6.655e-19
#   Max complementarity viol. (abs/rel) : 3.623e+03 / 1.294e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 127KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         43 rows           80 cols          144 elements
#       1200 qobjelem
# Presolved problem has:
#         22 rows           60 cols           84 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 127KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.50e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.50e+06] / [ 5.67e+03,  1.50e+06]
#   Objective      [min,max] : [ 5.39e-04,  7.54e-01] / [ 5.39e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.60e+06] / [ 1.00e-09,  1.60e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1171   Flops:        21484
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.95e+06   1.31e+00   3.32e+05  -8.6181169e+05   1.2090290e+08   1.4e+08
#    1   1.00e-06   3.79e-03   2.33e-10   7.4952554e+03   6.2505152e+06   6.2e+06
#    2   1.40e-07   5.25e-04   2.33e-10   6.6907271e+04   1.0777183e+06   1.0e+06
#    3   2.26e-10   2.12e-16   2.33e-10   1.4716696e+05   3.5578689e+05   2.1e+05
#    4   2.91e-10   2.48e-16   2.33e-10   1.8913317e+05   2.0764738e+05   1.9e+04
#    5   5.24e-10   1.29e-16   2.33e-10   1.9505862e+05   1.9665276e+05   1.6e+03
#    6   5.82e-11   1.55e-16   2.33e-10   1.9554038e+05   1.9565222e+05   1.1e+02
#    7   3.78e-10   1.53e-16   2.33e-10   1.9557961e+05   1.9558083e+05   1.2e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.954020768020560e+05
#   Max primal violation      (abs/rel) : 3.783e-10 / 3.783e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 8.923e+04 / 1.884e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 129KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          153 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           93 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 129KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.39e+02,  1.00e+06]
#   Objective      [min,max] : [ 6.44e-04,  7.54e-01] / [ 6.44e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.50e+06] / [ 1.00e-09,  3.50e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.68e-10   1.00e+03   0.00e+00  -3.5795968e+05   6.0000657e+10   6.0e+10
#    1   7.28e-11   1.25e+00   1.16e-10  -3.5791451e+05   7.4555578e+07   7.5e+07
#    2   1.02e-10   1.12e-01   1.16e-10  -3.1776854e+05   6.7898406e+06   7.1e+06
#    3   3.93e-10   2.22e-16   1.16e-10  -1.4028290e+05   8.0355217e+05   9.4e+05
#    4   2.91e-10   3.03e-16   1.16e-10   4.6243339e+04   1.6282811e+05   1.2e+05
#    5   5.82e-11   1.23e-16   1.16e-10   9.9229305e+04   1.1098402e+05   1.2e+04
#    6   1.02e-10   1.22e-16   1.16e-10   1.0484041e+05   1.0579111e+05   9.5e+02
#    7   2.47e-10   1.07e-16   1.16e-10   1.0512028e+05   1.0514547e+05   2.5e+01
#    8   7.28e-11   1.78e-16   1.16e-10   1.0512825e+05   1.0512856e+05   3.1e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.050717989319142e+05
#   Max primal violation      (abs/rel) : 7.276e-11 / 7.276e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.742e+04 / 1.103e-01
# [iter 001] max_rel_change=4.237e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:28, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 131KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 131KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.92e+03,  1.00e+06]
#   Objective      [min,max] : [ 6.52e-04,  7.54e-01] / [ 6.52e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  2.11e+06] / [ 1.00e-09,  2.11e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   7.90e+05   1.62e+00   3.29e+03  -3.6942948e+05   8.4386565e+07   8.6e+07
#    1   8.98e+03   1.84e-02   3.73e+01  -2.6437601e+05   1.7225904e+06   2.0e+06
# ...
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 231KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.20e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.20e+06] / [ 6.44e+02,  1.20e+06]
#   Objective      [min,max] : [ 6.36e-04,  7.54e-01] / [ 6.36e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.33e+06] / [ 1.00e-09,  2.31e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1186   Flops:        21506
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   1.78e+05   1.27e+00   1.21e+05   4.6505730e+04   9.2330909e+07   9.6e+07
#    1   7.01e-07   1.26e-01   2.33e-10   6.3129417e+04   1.4679141e+07   1.5e+07
#    2   4.76e-08   8.71e-03   2.33e-10   1.0160663e+05   1.3794891e+06   1.3e+06
#    3   5.09e-10   2.24e-16   2.33e-10   1.5607582e+05   2.8283856e+05   1.3e+05
#    4   7.28e-11   1.60e-16   2.33e-10   1.8427026e+05   1.9745223e+05   1.3e+04
#    5   3.20e-10   2.31e-16   2.33e-10   1.8824966e+05   1.8890852e+05   6.6e+02
#    6   1.75e-10   2.19e-16   2.33e-10   1.8846750e+05   1.8849400e+05   2.6e+01
#    7   3.78e-10   2.70e-16   2.33e-10   1.8847642e+05   1.8847647e+05   4.8e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.883660266216145e+05
#   Max primal violation      (abs/rel) : 3.783e-10 / 3.783e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 6.254e+04 / 1.386e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 233KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          146 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           86 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 233KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  6.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  6.00e+05] / [ 5.17e+03,  6.00e+05]
#   Objective      [min,max] : [ 6.42e-04,  7.54e-01] / [ 6.42e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.71e+05] / [ 1.00e-09,  1.03e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1178   Flops:        21082
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   5.08e+04   1.64e+00   5.72e+03  -5.9056148e+04   6.1058000e+07   6.1e+07
#    1   8.77e-07   5.00e-16   1.16e-10  -4.3820963e+04   1.9948935e+06   2.0e+06
#    2   2.55e-08   4.72e-16   1.16e-10   1.4355846e+05   5.3343912e+05   3.9e+05
#    3   3.06e-10   2.81e-16   1.16e-10   2.7658824e+05   3.1605874e+05   3.9e+04
#    4   2.18e-10   1.91e-16   1.16e-10   2.9562574e+05   2.9792150e+05   2.3e+03
#    5   2.18e-10   2.32e-16   1.16e-10   2.9649405e+05   2.9663681e+05   1.4e+02
#    6   1.46e-10   1.43e-16   1.16e-10   2.9653796e+05   2.9653837e+05   4.1e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   6 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 2.964810853569973e+05
#   Max primal violation      (abs/rel) : 1.455e-10 / 1.455e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 1.593e+04 / 4.424e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 236KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         45 rows           80 cols          151 elements
#       1200 qobjelem
# Presolved problem has:
#         24 rows           60 cols           91 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 236KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  9.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  9.00e+05] / [ 4.53e+02,  9.00e+05]
#   Objective      [min,max] : [ 6.42e-04,  7.54e-01] / [ 6.42e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.08e+06] / [ 1.00e-09,  1.34e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1256   Flops:        24614
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.51e+05   1.91e+00   2.13e+04  -1.8339200e+05   8.0609820e+07   8.3e+07
#    1   4.40e+05   8.83e-01   9.87e+03  -1.6467270e+05   3.7796274e+07   3.9e+07
#    2   2.42e+04   4.86e-02   5.44e+02  -1.4608874e+05   2.4013499e+06   2.6e+06
#    3   5.17e-08   2.22e-16   1.16e-10   7.7205979e+04   6.4384689e+05   5.7e+05
#    4   1.27e-09   1.67e-16   1.16e-10   1.9844485e+05   3.0726260e+05   1.1e+05
#    5   1.67e-10   2.36e-16   1.16e-10   2.2844372e+05   2.4060231e+05   1.2e+04
#    6   1.16e-10   1.45e-16   1.16e-10   2.3306384e+05   2.3412392e+05   1.1e+03
#    7   5.82e-11   1.67e-16   1.16e-10   2.3333770e+05   2.3337963e+05   4.2e+01
#    8   1.09e-10   2.23e-16   1.16e-10   2.3335329e+05   2.3335343e+05   1.4e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.332754520162967e+05
#   Max primal violation      (abs/rel) : 1.455e-10 / 1.455e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.124e+04 / 1.471e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 238KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          157 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           97 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 238KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  7.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  7.00e+05] / [ 3.09e+03,  7.00e+05]
#   Objective      [min,max] : [ 6.39e-04,  7.54e-01] / [ 6.39e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  1.41e+05] / [ 1.00e-09,  2.87e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   3.46e+05   2.44e+00   0.00e+00  -2.6761558e+04   6.3146897e+07   6.5e+07
#    1   1.92e+05   1.35e+00   1.16e-10  -4.2014484e+04   3.5341813e+07   3.6e+07
#    2   1.76e+04   1.24e-01   1.16e-10  -2.2370983e+04   3.8961319e+06   4.0e+06
#    3   2.27e-07   2.22e-16   1.16e-10   2.5563628e+05   1.1298722e+06   8.7e+05
#    4   3.94e-09   4.44e-16   1.16e-10   3.9204028e+05   4.6209393e+05   7.0e+04
#    5   1.16e-10   2.22e-16   1.16e-10   4.2861233e+05   4.3446278e+05   5.9e+03
#    6   1.75e-10   2.22e-16   1.16e-10   4.3159097e+05   4.3200383e+05   4.1e+02
#    7   1.84e-10   2.29e-16   1.16e-10   4.3165443e+05   4.3165764e+05   3.2e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 4.315838821260207e+05
#   Max primal violation      (abs/rel) : 1.837e-10 / 1.837e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 1.234e+04 / 2.712e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 240KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          152 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           92 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 240KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  4.00e+05] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  4.00e+05] / [ 2.91e+02,  4.00e+05]
#   Objective      [min,max] : [ 6.41e-04,  7.54e-01] / [ 6.41e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  7.55e+04] / [ 1.00e-09,  4.72e-07]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1195   Flops:        21990
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.81e+05   2.33e+00   0.00e+00   3.3475089e+04   3.5182185e+07   3.6e+07
#    1   1.41e+05   1.17e+00   0.00e+00   1.5623469e+04   1.7967825e+07   1.8e+07
#    2   1.97e+04   1.64e-01   5.82e-11   1.7576336e+04   2.7142768e+06   2.7e+06
#    3   3.92e+02   4.57e-04   5.82e-11   9.1956137e+04   6.6213364e+05   5.7e+05
#    4   7.17e+00   6.13e-06   5.82e-11   1.8389955e+05   2.3971167e+05   5.6e+04
#    5   1.57e-01   9.52e-08   5.82e-11   2.1214157e+05   2.1685753e+05   4.7e+03
#    6   5.61e-03   3.23e-09   5.82e-11   2.1434238e+05   2.1468808e+05   3.5e+02
#    7   8.73e-05   5.25e-11   5.82e-11   2.1444260e+05   2.1445035e+05   7.7e+00
#    8   2.75e-08   1.66e-14   5.82e-11   2.1444591e+05   2.1444598e+05   6.6e-02
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 2.144127251341431e+05
#   Max primal violation      (abs/rel) : 2.743e-08 / 2.743e-08
#   Max dual violation        (abs/rel) : 5.741e-13 / 1.435e-18
#   Max complementarity viol. (abs/rel) : 3.623e+03 / 1.294e-02
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 243KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         43 rows           80 cols          144 elements
#       1200 qobjelem
# Presolved problem has:
#         22 rows           60 cols           84 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 243KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.50e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.50e+06] / [ 5.67e+03,  1.50e+06]
#   Objective      [min,max] : [ 5.38e-04,  7.54e-01] / [ 5.38e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.60e+06] / [ 1.00e-09,  1.60e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1171   Flops:        21484
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   2.95e+06   1.31e+00   3.32e+05  -8.6190387e+05   1.2090289e+08   1.4e+08
#    1   1.00e-06   3.79e-03   2.33e-10   7.4156621e+03   6.2504192e+06   6.2e+06
#    2   1.41e-07   5.25e-04   2.33e-10   6.6862354e+04   1.0776940e+06   1.0e+06
#    3   3.06e-10   1.54e-16   2.33e-10   1.4714689e+05   3.5577166e+05   2.1e+05
#    4   4.37e-10   1.38e-16   2.33e-10   1.8913484e+05   2.0759109e+05   1.8e+04
#    5   3.20e-10   1.52e-16   2.33e-10   1.9504308e+05   1.9664325e+05   1.6e+03
#    6   2.33e-10   1.34e-16   2.33e-10   1.9552753e+05   1.9564017e+05   1.1e+02
#    7   5.82e-11   1.04e-16   2.33e-10   1.9556706e+05   1.9556828e+05   1.2e+00
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   7 barrier iterations in 0.01 seconds at time 0
#
# Final objective                       : 1.953896127557476e+05
#   Max primal violation      (abs/rel) : 5.821e-11 / 5.821e-11
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 8.923e+04 / 1.884e-01
# FICO Xpress v9.5.0, Hyper, solve started 1:04:30, Aug 13, 2025
# Heap usage: 429KB (peak 450KB, 245KB system)
# Maximizing QP noname using up to 8 threads and up to 15GB memory, with these control settings:
# OUTPUTLOG = 1
# NLPPOSTSOLVE = 1
# XSLP_DELETIONCONTROL = 0
# XSLP_OBJSENSE = -1
# Original problem has:
#         44 rows           80 cols          153 elements
#       1200 qobjelem
# Presolved problem has:
#         23 rows           60 cols           93 elements
#        592 qobjelem
# Presolve finished in 0 seconds
# Heap usage: 457KB (peak 481KB, 245KB system)
#
# Coefficient range                    original                 solved
#   Coefficients   [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.00e+00,  1.00e+00]
#   RHS and bounds [min,max] : [ 1.00e+00,  1.00e+06] / [ 1.39e+02,  1.00e+06]
#   Objective      [min,max] : [ 6.43e-04,  7.54e-01] / [ 6.43e-04,  7.54e-01]
#   Quadratic      [min,max] : [ 4.94e-11,  3.50e+06] / [ 1.00e-09,  3.50e-06]
# Autoscaling applied standard scaling
#
# Using AVX2 support
# Cores per CPU (CORESPERCPU): 8
# Barrier starts after 0 seconds, using up to 8 threads, 4 cores
# Matrix ordering - Dense cols.:     44   NZ(L):      1189   Flops:        21644
#
#   Its   P.inf      D.inf      U.inf      Primal obj.     Dual obj.      Compl.
#    0   9.68e-10   1.00e+03   0.00e+00  -3.5801791e+05   6.0000657e+10   6.0e+10
#    1   1.31e-10   1.25e+00   1.16e-10  -3.5797273e+05   7.4555441e+07   7.5e+07
#    2   1.31e-10   1.12e-01   1.16e-10  -3.1782263e+05   6.7897827e+06   7.1e+06
#    3   3.35e-10   1.67e-16   1.16e-10  -1.4031506e+05   8.0351059e+05   9.4e+05
#    4   1.31e-10   2.41e-16   1.16e-10   4.6237367e+04   1.6279831e+05   1.2e+05
#    5   1.16e-10   1.43e-16   1.16e-10   9.9226523e+04   1.1097768e+05   1.2e+04
#    6   1.75e-10   1.33e-16   1.16e-10   1.0483495e+05   1.0578599e+05   9.5e+02
#    7   2.76e-10   2.07e-16   1.16e-10   1.0511520e+05   1.0514062e+05   2.5e+01
#    8   1.02e-10   2.27e-16   1.16e-10   1.0512330e+05   1.0512364e+05   3.4e-01
# Barrier method finished in 0 seconds
# Uncrunching matrix
# Optimal solution found
# Barrier solved problem
#   8 barrier iterations in 0.00 seconds at time 0
#
# Final objective                       : 1.050668672700266e+05
#   Max primal violation      (abs/rel) : 1.019e-10 / 1.019e-10
#   Max dual violation        (abs/rel) :       0.0 /       0.0
#   Max complementarity viol. (abs/rel) : 4.744e+04 / 1.104e-01
# [iter 006] max_rel_change=2.164e-07
# Converged at iter 6
# [CHECK] annual pooled cost (1x) = 129,668.17
# [CHECK] sum(cost_each)         = 129,668.17
# ✔ 已生成 nash_holdings_dollar.csv, nash_holdings_weight.csv, nash_components.csv, nash_total_cost.txt
